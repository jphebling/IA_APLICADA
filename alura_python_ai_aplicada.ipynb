# %% [markdown]
# <a href="https://colab.research.google.com/github/jphebling/IA_APLICADA/blob/main/alura_python_ai_aplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

from google.colab import userdata
os.environ['GOOGLE_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model='gemini-2.5-flash', contents="O que é Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar máquinas e sistemas que podem realizar tarefas que, tradicionalmente, exigiriam inteligência humana. Em essência, a IA busca simular e automatizar processos cognitivos humanos.
#
# ### O que a IA pode fazer?
#
# Máquinas com IA são projetadas para:
#
# 1.  **Aprender:** Adquirir informações e regras para usar as informações. Elas aprendem com dados, identificando padrões e fazendo previsões ou decisões com base nesses padrões (isto é, **Machine Learning**).
# 2.  **Raciocinar:** Usar regras para chegar a conclusões aproximadas ou definitivas.
# 3.  **Resolver Problemas:** Encontrar soluções para desafios complexos.
# 4.  **Perceber:** Processar informações sensoriais, como imagens (visão computacional) ou fala (processamento de linguagem natural).
# 5.  **Compreender Linguagem Natural:** Interagir com humanos usando a linguagem do dia a dia.
# 6.  **Tomar Decisões:** Fazer escolhas com base em dados e objetivos.
#
# ### Como a IA funciona?
#
# A IA geralmente se baseia em:
#
# *   **Algoritmos:** Conjuntos de regras e instruções que a máquina segue para realizar uma tarefa.
# *   **Dados:** Grandes volumes de informações que os algoritmos utilizam para aprender, identificar padrões e tomar decisões.
# *   **Modelos:** Estruturas matemáticas que são treinadas com os dados para realizar uma função específica (por exemplo, classificar imagens, prever resultados).
#
# ### Tipos de IA:
#
# É comum classificar a IA em diferentes níveis:
#
# 1.  **IA Fraca (ou IA Estreita/Narrow AI):** É o tipo de IA que existe hoje. Ela é projetada e treinada para uma tarefa específica.
#     *   **Exemplos:** Assistentes de voz (Siri, Alexa), sistemas de recomendação (Netflix, Amazon), filtros de spam, carros autônomos, sistemas de reconhecimento facial, IA generativa (como ChatGPT).
# 2.  **IA Forte (ou IA Geral/General AI - AGI):** É uma IA hipotética que possuiria a capacidade intelectual de um ser humano em todas as tarefas cognitivas. Ela poderia aprender, compreender e aplicar o conhecimento em uma ampla gama de problemas, assim como um humano. Ainda não existe.
# 3.  **Superinteligência Artificial (ASI):** Um estágio hipotético onde a IA superaria a inteligência humana em todos os aspectos, incluindo criatividade, resolução de problemas e habilidades sociais.
#
# ### Subcampos Importantes da IA:
#
# *   **Machine Learning (Aprendizado de Máquina):** Permite que os sistemas aprendam com dados, sem serem explicitamente programados. É o motor por trás da maioria das aplicações de IA atuais.
# *   **Deep Learning (Aprendizado Profundo):** Um subcampo do Machine Learning que utiliza redes neurais artificiais com múltiplas camadas (inspiradas no cérebro humano) para aprender padrões complexos de dados.
# *   **Natural Language Processing (Processamento de Linguagem Natural - PNL):** Foca em permitir que os computadores compreendam, interpretem e gerem a linguagem humana.
# *   **Computer Vision (Visão Computacional):** Habilita as máquinas a "ver" e interpretar imagens e vídeos digitais.
# *   **Robótica:** Embora nem todo robô use IA, a combinação de robótica com IA permite que as máquinas executem tarefas físicas de forma autônoma e inteligente.
# *   **Reinforcement Learning (Aprendizado por Reforço):** Um tipo de ML onde a IA aprende a tomar decisões agindo em um ambiente e recebendo feedback (recompensas ou punições).
#
# ### Aplicações da IA no Dia a Dia:
#
# *   **Saúde:** Diagnóstico de doenças, descoberta de medicamentos.
# *   **Finanças:** Detecção de fraudes, previsão de mercado.
# *   **Transporte:** Carros autônomos, otimização de rotas.
# *   **Educação:** Plataformas de aprendizado personalizadas.
# *   **Entretenimento:** Sistemas de recomendação de conteúdo, criação de arte e música.
# *   **Atendimento ao Cliente:** Chatbots e assistentes virtuais.
#
# A Inteligência Artificial é um campo em constante evolução, com o potencial de transformar radicalmente diversos aspectos da nossa sociedade e da vida humana.

# %%
chat = client.chats.create(model='gemini-2.5-flash')

# %%
resposta = chat.send_message("O que é Inteligência Artificial?")
print(resposta.text)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# /tmp/ipython-input-3276429515.py in <cell line: 0>()
# ----> 1 resposta = chat.send_message("O que é Inteligência Artificial?")
#       2 print(resposta.text)
#
# /usr/local/lib/python3.12/dist-packages/google/genai/chats.py in send_message(self, message, config)
#     252       )
#     253     input_content = t.t_content(message)
# --> 254     response = self._modules.generate_content(
#     255         model=self._model,
#     256         contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5004     while remaining_remote_calls_afc > 0:
#    5005       i += 1
# -> 5006       response = self._generate_content(
#    5007           model=model, contents=contents, config=parsed_config
#    5008       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    3816     request_dict = _common.encode_unserializable_types(request_dict)
#    3817
# -> 3818     response = self._api_client.request(
#    3819         'post', path, request_dict, http_options
#    3820     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1312         http_method, path, request_dict, http_options
#    1313     )
# -> 1314     response = self._request(http_request, http_options, stream=False)
#    1315     response_body = (
#    1316         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1148         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1149
# -> 1150     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1151
#    1152   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     416                 retry_exc = self.retry_error_cls(fut)
#     417                 if self.reraise:
# --> 418                     raise retry_exc.reraise()
#     419                 raise retry_exc from fut.exception()
#     420
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183     def reraise(self) -> t.NoReturn:
#     184         if self.last_attempt.failed:
# --> 185             raise self.last_attempt.result()
#     186         raise self
#     187
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1125           timeout=http_request.timeout,
#    1126       )
# -> 1127       errors.APIError.raise_for_response(response)
#    1128       return HttpResponse(
#    1129           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     108       raise ClientError(status_code, response_json, response)
#     109     elif 500 <= status_code < 600:
# --> 110       raise ServerError(status_code, response_json, response)
#     111     else:
#     112       raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
chat.get_history()
