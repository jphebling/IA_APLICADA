# %% [markdown]
# <a href="https://colab.research.google.com/github/jphebling/IA_APLICADA/blob/main/alura_python_ai_aplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

from google.colab import userdata
os.environ['GOOGLE_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model='gemini-2.5-flash', contents="O que é Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar sistemas e máquinas que conseguem realizar tarefas que normalmente exigiriam inteligência humana.
#
# Em sua essência, a IA busca simular processos cognitivos humanos, como:
#
# 1.  **Aprendizado:** A capacidade de adquirir conhecimento e regras para usar esse conhecimento. Muitos sistemas de IA "aprendem" a partir de grandes quantidades de dados, identificando padrões.
# 2.  **Raciocínio:** A capacidade de usar regras para chegar a conclusões aproximadas ou definitivas.
# 3.  **Resolução de Problemas:** Encontrar soluções para problemas específicos, muitas vezes por tentativa e erro ou otimização.
# 4.  **Percepção:** A capacidade de processar informações sensoriais (como imagens, sons, texto) do ambiente e interpretá-las.
# 5.  **Compreensão da Linguagem Natural:** A capacidade de entender e gerar linguagem humana.
# ...

# %%
chat = client.chats.create(model='gemini-2.5-flash')

# %%
resposta = chat.send_message("O que é Inteligência Artificial?")
print(resposta.text)
# Out:
# **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado à criação de sistemas ou máquinas capazes de simular a inteligência humana. O objetivo é permitir que essas máquinas realizem tarefas que normalmente exigiriam capacidade cognitiva humana, como aprender, raciocinar, perceber, compreender a linguagem e tomar decisões.
#
# Em termos mais simples, a IA busca fazer com que computadores e softwares "pensem" e ajam de maneira "inteligente".
#
# ### Principais Características e Habilidades da IA:
#
# 1.  **Aprendizado (Machine Learning - ML):** A IA aprende com dados, identificando padrões e fazendo previsões ou tomando decisões sem ser explicitamente programada para cada cenário. Por exemplo, um sistema pode aprender a reconhecer gatos em fotos ao ser exposto a milhares de imagens de gatos e não-gatos.
# ...

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='O que é Inteligência Artificial?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""**Inteligência Artificial (IA)** é um campo da ciência da computação dedicado à criação de sistemas ou máquinas capazes de simular a inteligência humana. O objetivo é permitir que essas máquinas realizem tarefas que normalmente exigiriam capacidade cognitiva humana, como aprender, raciocinar, perceber, compreender a linguagem e tomar decisões.
#
#  Em termos mais simples, a IA busca fazer com que computadores e softwares "pensem" e ajam de maneira "inteligente".
#
#  ### Principais Características e Habilidades da IA:
#
# ...

# %%
prompt = input("Digite a sua pergunta: ")
while prompt != "fim":
  resposta = chat.send_message(prompt)
  print(resposta.text)
  print("\n")
  prompt = input("Digite a sua pergunta: ")
# Out:
# Digite a sua pergunta: O que é ia
# **IA** é a sigla para **Inteligência Artificial**.
#
# É um campo da ciência da computação que se dedica a criar sistemas ou máquinas capazes de **simular a inteligência humana**. O objetivo é que esses sistemas possam aprender, raciocinar, perceber, compreender a linguagem e tomar decisões, realizando tarefas que normalmente exigiriam capacidade cognitiva humana.
#
# Pense em exemplos como assistentes de voz (Siri, Alexa), sistemas de recomendação (Netflix, Spotify) ou carros autônomos.
#
#
# Digite a sua pergunta: fim
