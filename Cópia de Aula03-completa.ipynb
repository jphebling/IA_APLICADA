# %% [markdown]
# # Módulo 3

# %% [markdown]
# ### Estrutura de repetição, loop: "for"

# %%
dict_desafio = [
    {"nome": "Maria Silva", "média": 8.9},
    {"nome": "João Santos", "média": 7.5},
    {"nome": "Ana Oliveira", "média": 4.2},
    {"nome": "Pedro Costa", "média": 1.4}
]

# %%
n = 0

while n < len(dict_desafio):
    print(dict_desafio[n])
    n += 1
# Out:
# {'nome': 'Maria Silva', 'média': 8.9}
# {'nome': 'João Santos', 'média': 7.5}
# {'nome': 'Ana Oliveira', 'média': 4.2}
# {'nome': 'Pedro Costa', 'média': 1.4}

# %%
for elemento in dict_desafio:
    print(elemento)
# Out:
# {'nome': 'Maria Silva', 'média': 8.9}
# {'nome': 'João Santos', 'média': 7.5}
# {'nome': 'Ana Oliveira', 'média': 4.2}
# {'nome': 'Pedro Costa', 'média': 1.4}

# %%
for n in range(5):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for n in range(2, 7):
    print(n)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
for n in range(2, 7, 3):
    print(n)
# Out:
# 2
# 5

# %%
pessoa = {
    "nome": "Fabrício",
    "idade": 19,
    "altura": 1.87
}

print(pessoa)
# Out:
# {'nome': 'Fabrício', 'idade': 19, 'altura': 1.87}

# %%
for chave in pessoa:
    print(chave)
# Out:
# nome
# idade
# altura

# %%
pessoa.items()
# Out:
# dict_items([('nome', 'Fabrício'), ('idade', 19), ('altura', 1.87)])

# %%
pessoa.keys()
# Out:
# dict_keys(['nome', 'idade', 'altura'])

# %%
pessoa.values()
# Out:
# dict_values(['Fabrício', 19, 1.87])

# %%
for chave, valor in pessoa.items():
    print(f"A chave é {chave} e o valor é {valor}.")
# Out:
# A chave é nome e o valor é Fabrício.
# A chave é idade e o valor é 19.
# A chave é altura e o valor é 1.87.

# %%
for n in range(11):
    if n % 2 == 0:
        print(n)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for n in range(11):
    if n % 3 == 0:
        print(n)
# Out:
# 0
# 3
# 6
# 9

# %% [markdown]
# ### Funções

# %%
texto1 = "   Fabrício CARRaro  da alura   "
texto2 = "mArIA   aNA    sAntoS   pereiRA"
texto3 = "  PeDRO   alvaRes   cabrAl "
texto4 = "   anA   caroLINa     FerreirA  "
texto5 = "  rObertO    carlOS      OliveiRa  "

# %%
texto1.split()
# Out:
# ['Fabrício', 'CARRaro', 'da', 'alura']

# %%
len(texto1.split())
# Out:
# 4

# %%
def escreve_texto_corretamente(texto):
    texto_novo = texto.upper()
    lista_de_palavras = texto_novo.split()
    nome_final = " ".join(lista_de_palavras)
    return nome_final

# %%
escreve_texto_corretamente(texto1)
# Out:
# 'FABRÍCIO CARRARO DA ALURA'

# %%
escreve_texto_corretamente(texto2)
# Out:
# 'MARIA ANA SANTOS PEREIRA'

# %%
escreve_texto_corretamente(texto3)
# Out:
# 'PEDRO ALVARES CABRAL'

# %%
def escreve_texto_corretamente_alternativa(texto):
    print(" ".join(texto.upper().split()))

# %%
escreve_texto_corretamente_alternativa(texto1)
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
salas_de_aula = ["Sala 1", "Sala 2", "Sala 3"]

# %%
import random

def aloca_alunos_em_salas(nome_do_aluno, lista_de_salas):
    sala_do_aluno = random.choice(lista_de_salas)

    dict_aluno = {
        "nome":nome_do_aluno,
        "sala":sala_do_aluno
    }
    print(dict_aluno)

# %%
aloca_alunos_em_salas(texto1, salas_de_aula)
# Out:
# {'nome': '   Fabrício CARRaro  da alura   ', 'sala': 'Sala 3'}

# %%
nome_processado = escreve_texto_corretamente(texto1)
aloca_alunos_em_salas(nome_processado, ["Classe 1", "Classe 2", "Classe 3"])
# Out:
# {'nome': 'FABRÍCIO CARRARO DA ALURA', 'sala': 'Classe 1'}

# %% [markdown]
# Desafio:
# <br>
# 1. Pedir pra uma IA gerar em Python uma lista de 20 emails pra você.
# 2. Criar uma função que vai receber como argumento/parâmetro uma lista de emails, percorrer essa lista de emails, e, para cada email da lista,
# ela irá chamar a IA do Gemini via API e pedir pra ela resumir pra você cada email em apenas 1 linha, definindo o que essa pessoa queria no email

# %%
email_bodies = [
    """
    Olá, equipe!

    Gostaria de informar que a reunião de planejamento para o próximo trimestre foi remarcada para a próxima sexta-feira, às 10h.
    Por favor, confirmem sua presença.

    Atenciosamente,
    João Silva
    """,
    """
    Prezados clientes,

    Nossa plataforma passará por uma atualização de sistema na madrugada de sábado para domingo.
    O serviço poderá ficar indisponível por algumas horas. Pedimos desculpas por qualquer transtorno.

    Atenciosamente,
    Equipe de Suporte
    """,
    """
    Oi, Maria!

    Tudo bem? Estou te escrevendo para saber se você recebeu o relatório que te enviei ontem.
    Precisamos fechar a análise até o final da semana. Me avise se precisar de algo.

    Abraços,
    Carlos
    """,
    """
    Caros colaboradores,

    Lembramos que o prazo para a entrega dos holerites de dezembro se encerra na próxima segunda-feira.
    Qualquer dúvida, por favor, entrem em contato com o departamento de RH.

    Obrigado,
    Recursos Humanos
    """,
    """
    Olá,

    Confirmamos o recebimento do seu pedido #12345. Ele já está em processamento e você receberá um novo email
    com o código de rastreamento assim que for enviado.

    Obrigado por comprar conosco!
    """,
    """
    Bom dia,

    Escrevo para formalizar o pedido de férias de 15 dias, com início previsto para o dia 20 de agosto.
    Aguardo a aprovação.

    Obrigado,
    André Costa
    """,
    """
    Olá, Fernando,

    Gostaria de agradecer a sua participação no nosso último webinar.
    Seu feedback foi muito importante para nós. Em anexo, segue o material completo apresentado.

    Atenciosamente,
    Time de Marketing
    """,
    """
    Prezado(a) [Nome do Cliente],

    A sua fatura mensal no valor de R$ [valor] referente aos serviços de [serviço] está disponível.
    Você pode acessá-la e realizar o pagamento através do nosso portal do cliente.

    Atenciosamente,
    Equipe Financeira
    """,
    """
    Oi, Ana!

    Que tal sairmos para almoçar na quarta-feira?
    Pensei naquele restaurante novo que abriu perto do escritório.
    Me avisa se você puder.

    Beijos,
    Lúcia
    """,
    """
    Prezados fornecedores,

    Gostaria de solicitar um orçamento detalhado para a compra de 500 unidades do produto X.
    Aguardamos o retorno o mais breve possível.

    Cordialmente,
    Departamento de Compras
    """,
    """
    Olá, Pedro,

    Recebi seu currículo e achei seu perfil bastante interessante para a vaga de Desenvolvedor Júnior.
    Gostaria de agendar uma entrevista para a próxima semana. Poderia nos informar sua disponibilidade?

    Obrigado,
    Recrutamento e Seleção
    """,
    """
    Bom dia,

    Estamos com problemas técnicos em nossa rede.
    Nossa equipe já está trabalhando para resolver a situação e normalizar o serviço o mais rápido possível.

    Agradecemos a compreensão.
    """,
    """
    Prezado Sr. Antônio,

    Escrevo para confirmar nossa reunião agendada para amanhã, às 14h, em sua sala.
    Estaremos discutindo a proposta de projeto que lhe enviamos.

    Atenciosamente,
    Mariana Fontes
    """
]

# %%
import os

from google.colab import userdata
os.environ['GOOGLE_API_KEY'] = userdata.get('GEMINI_API_KEY')

from google import genai
client = genai.Client()

# %%
def resumidor_de_emails_joao(lista_de_corpos_de_email):
  lista_de_resumo_emails = []
  for numero, corpo in enumerate(lista_de_corpos_de_email):
    chat = client.chats.create(model='gemini-2.5-flash')
    resposta = chat.send_message(f"""Estou colocando em seguida o corpo de um email. Preciso que analise o texto
    e faça um resumo de no máximo uma linha do objetivo deste email. Segue o corpo do email {corpo}""")
    print(f"E-mail {numero + 1}: {resposta.text}")
    lista_de_resumo_emails.append(f"E-mail {numero + 1}: {resposta.text}")
    print("-" * 50)

  return lista_de_resumo_emails

# %%
resumidor_de_emails_joao(email_bodies)
# Out:
# E-mail 1: O objetivo do email é **comunicar o reagendamento da reunião de planejamento e solicitar a confirmação de presença.**
# --------------------------------------------------
# E-mail 2: O objetivo deste email é **informar os clientes sobre uma atualização de sistema programada e a possível indisponibilidade do serviço.**
# --------------------------------------------------
# E-mail 3: O objetivo do email é **solicitar a Maria a confirmação do recebimento de um relatório, essencial para a conclusão de uma análise com prazo até o final da semana.**
# --------------------------------------------------
# E-mail 4: O objetivo do email é: **Relembrar os colaboradores sobre o prazo final para a entrega dos holerites de dezembro.**
# --------------------------------------------------
# E-mail 5: O objetivo é confirmar o recebimento e o processamento do pedido, informando sobre o futuro envio do código de rastreamento.
# --------------------------------------------------
# E-mail 6: O objetivo do e-mail é **formalizar o pedido de férias de 15 dias de André Costa para aprovação.**
# --------------------------------------------------
# E-mail 7: O objetivo deste email é agradecer a participação no webinar e enviar o material de apresentação.
# --------------------------------------------------
# E-mail 8: O objetivo deste email é **informar sobre a disponibilidade da fatura mensal e orientar para acesso e pagamento.**
# --------------------------------------------------
# E-mail 9: O objetivo do email é convidar Ana para um almoço na quarta-feira e verificar sua disponibilidade.
# --------------------------------------------------
# E-mail 10: O e-mail solicita um orçamento detalhado para a compra de 500 unidades do produto X.
# --------------------------------------------------
# E-mail 11: O objetivo deste email é **solicitar a disponibilidade de Pedro para agendar uma entrevista para a vaga de Desenvolvedor Júnior.**
# --------------------------------------------------
# E-mail 12: O objetivo é informar sobre problemas técnicos na rede e as ações em andamento para sua resolução.
# --------------------------------------------------
# E-mail 13: O objetivo deste e-mail é confirmar a reunião agendada para amanhã para discutir a proposta de projeto.
# --------------------------------------------------
# ['E-mail 1: O objetivo do email é **comunicar o reagendamento da reunião de planejamento e solicitar a confirmação de presença.**',
#  'E-mail 2: O objetivo deste email é **informar os clientes sobre uma atualização de sistema programada e a possível indisponibilidade do serviço.**',
#  'E-mail 3: O objetivo do email é **solicitar a Maria a confirmação do recebimento de um relatório, essencial para a conclusão de uma análise com prazo até o final da semana.**',
#  'E-mail 4: O objetivo do email é: **Relembrar os colaboradores sobre o prazo final para a entrega dos holerites de dezembro.**',
#  'E-mail 5: O objetivo é confirmar o recebimento e o processamento do pedido, informando sobre o futuro envio do código de rastreamento.',
#  'E-mail 6: O objetivo do e-mail é **formalizar o pedido de férias de 15 dias de André Costa para aprovação.**',
#  'E-mail 7: O objetivo deste email é agradecer a participação no webinar e enviar o material de apresentação.',
#  'E-mail 8: O objetivo deste email é **informar sobre a disponibilidade da fatura mensal e orientar para acesso e pagamento.**',
#  'E-mail 9: O objetivo do email é convidar Ana para um almoço na quarta-feira e verificar sua disponibilidade.',
#  'E-mail 10: O e-mail solicita um orçamento detalhado para a compra de 500 unidades do produto X.',
#  'E-mail 11: O objetivo deste email é **solicitar a disponibilidade de Pedro para agendar uma entrevista para a vaga de Desenvolvedor Júnior.**',
#  'E-mail 12: O objetivo é informar sobre problemas técnicos na rede e as ações em andamento para sua resolução.',
#  'E-mail 13: O objetivo deste e-mail é confirmar a reunião agendada para amanhã para discutir a proposta de projeto.']

# %% [markdown]
# ### Rodando um modelo aberto via Groq

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 5.3 MB/s eta 0:00:00

# %%
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %%
from groq import Groq

client_groq = Groq()

completion = client_groq.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "user",
        "content": "De que é feito o Sol?"
      }
    ],
    temperature=1, #0 - o menos criativo possível; 2 - o mais criativo possível
    max_completion_tokens=8192,
    reasoning_effort="medium",
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# O Sol não é um objeto sólido; é uma enorme esfera de plasma – gás ionizado – que, em essência, é feita de dois elementos principais:
#
# | Elemento | Porcentagem aproximada (massa) | Função na estrutura solar |
# |----------|-------------------------------|---------------------------|
# | Hidrogênio (H) | ~74 % | Fonte primária de energia via fusão nuclear (H → He). |
# | Hélio (He) | ~24 % | Produto da fusão de hidrogênio; concentra‑se na zona externa. |
# | “Metais” (tudo que não é H ou He) | ~2 % | Inclui oxigênio, carbono, silício, ferro, etc. Contribui para a opacidade e para a formação de elementos mais pesados nas reações nucleares. |
#
# ### Como esses componentes se organizam?
#
# 1. **Núcleo (core)** – a região central onde a temperatura atinge ~15 milhões de K. Aqui ocorre a fusão de hidrogênio em hélio (principamente o ciclo próton‑próton). O calor gerado sustenta o equilíbrio de pressão que impede o colapso.
#
# 2. **Zona Radiativa** – entre o núcleo e a zona convectiva. A energia viaja por radiação, com o material sendo muito denso e quente.
#
# 3. **Zona Convectiva** – onde a temperatura cai para ~2 milhões de K. A energia é transportada por convecção (bolhas de plasma quente subindo e esfriando), formando os famosos “granulações” observadas na superfície.
#
# 4. **Fotosfera** – a “superfície” visível. É onde a luz que vemos é emitida. Embora não seja sólida, a fotosfera tem uma espessura de apenas cerca de 500 km.
#
# 5. **Camadas superiores (cromosfera, corona)** – regiões mais frias (cromosfera) e extremamente quentes (corona, milhões de K) que se estendem muito além da fotosfera.
#
# ### Como sabemos disso?
#
# - **Espectroscopia solar**: Analisando a luz do Sol, vemos linhas de absorção e emissão que identificam elementos e suas abundâncias.
# - **Modelos heliográficos**: Equações de estado e de transporte de energia são resolvidas numericamente para reproduzir o comportamento observado.
# - **Estudo de reações nucleares**: A produção de neutrinos do Sol, detectados na Terra, confirma o processo de fusão de hidrogênio em hélio.
#
# Em resumo, o Sol é principalmente hidrogênio ionizado, com um quarto de hélio e um pouco de elementos mais pesados, todo esse material sustentado em equilíbrio por pressões radiativa e convectiva dentro de um plasma quente e dinâmico.
